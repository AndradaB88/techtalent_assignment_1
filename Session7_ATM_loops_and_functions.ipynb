# %% [markdown]
# <a href="https://colab.research.google.com/github/AndradaB88/techtalent_assignment_1/blob/main/Session7_ATM_loops_and_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
# setting up a pin number
pin = "1234"
# displaying the generated balance only for monitoring if the code gives the right output
print(balance)


print("Hello !")
print ("Welcome to the Northen Frock Bank")

def pin_entry(inp_pin) :
  balance = round(random.uniform(0.00,100.00),2)
  if inp_pin == pin :
      keep_going = True
      while keep_going == True :
        print(main_menu_message)
        main_menu = int(input())
        if main_menu == 1 :
            print(f"Your current balance is :£{round(balance,2)}")
            print(main_menu_message)
        elif main_menu == 2 :
            withdrawal_menu = int(input("Please select withdrawal amount : \n 1 - £10 \n 2 - £20 \n 3 - £40 \n 4 - £60 \n 5 - £80 \n 6 - £100 \n 7 - Other amount \n 8 - Return to main menu \n"))
            if withdrawal_menu == 1 :
                if  balance >= 10 :
                  balance = balance - 10
                  print(f"You have withdrawn £10. Your new balance is: £{round(balance,2)}")
                  print(main_menu_message)
                else: 
                  print ("Sorry, you have insufficient funds. Please try again later")
                  print(main_menu_message)

            elif withdrawal_menu == 2 : 
              if balance >= 20 :
                balance = balance - 20
                print(f"You have withdrawn £20. Your new balance is: £{round(balance,2)}")
                print(main_menu_message)
              else: 
                print ("Sorry, you have insufficient funds. Please try again later")
                print(main_menu_message)
  
            elif withdrawal_menu == 3 :
              if balance >= 40 :
                balance = balance - 40
                print(f"You have withdrawn £40. Your new balance is: £{round(balance,2)}")
                print(main_menu_message)
              else: 
                print ("Sorry, you have insufficient funds. Please try again later")
                print(main_menu_message)

            elif withdrawal_menu == 4 :
              if balance >= 60 :
                balance = balance - 60
                print(f"You have withdrawn £60. Your new balance is: £{round(balance,2)}")
                print(main_menu_message)
              else: 
                print ("Sorry, you have insufficient funds. Please try again later")
                print(main_menu_message)

            elif withdrawal_menu == 5 :
              if balance >= 80 :
                balance = balance - 80
                print(f"You have withdrawn £80. Your new balance is: £{round(balance,2)}")
                print(main_menu_message)
              else: 
                print ("Sorry, you have insufficient funds. Please try again later")
                print(main_menu_message)
  
            elif withdrawal_menu == 6 : 
              if balance >= 100 :
                balance = balance - 100
                print(f"You have withdrawn £100. Your new balance is: £{round(balance,2)}")
                print(main_menu_message)
              else: 
                print ("Sorry, you have insufficient funds. Please try again later")
                print(main_menu_message)

            elif withdrawal_menu == 7 :
              requested_amount = int(input("Please enter the amount:"))
              if requested_amount < balance and requested_amount%10 == 0:
                balance = balance - requested_amount
                print(f"You have withdrawn £{requested_amount}. Your new balance is:£{round(balance,2)}")
                print(main_menu_message)
              else: 
                print ("Sorry, we could not perform your request.")
                print(main_menu_message)
  
            elif withdrawal_menu == 8 :
                print(main_menu_message)

        elif main_menu == 3 :
          deposit_menu = int(input("Please select the amount you would like to deposit : \n 1 - £10 \n 2 - £20 \n 3 - £40 \n 4 - £60 \n 5 - £80 \n 6 - £100 \n 7 - Other amount \n 8 - Return to main menu\n"))
          if deposit_menu == 1 :
              balance = balance + 10
              print(f"You have added £10. Your new balance is: {round(balance,2)}")
              print(main_menu_message)
          elif deposit_menu == 2 : 
            balance = balance + 20
            print(f"You have added £20. Your new balance is: {round(balance,2)} ")
            print(main_menu_message)      
  
          elif deposit_menu == 3 :  
            balance = balance + 40
            print(f"You have added £40.Your new balance is: {round(balance,2)}")
            print(main_menu_message)      

          elif deposit_menu == 4 :
            balance = balance + 60
            print(f"You have added £60. Your new balance is:{round(balance,2)}")
            print(main_menu_message)      

          elif deposit_menu == 5 :
            balance = balance + 80
            print(f"You have added £80. Your new balance is:{round(balance,2)}")
            print(main_menu_message)      
  
          elif deposit_menu == 6 : 
            balance = balance + 100
            print(f"You have added £100. Your new balance is:{round(balance,2)}")
            print(main_menu_message)      

          elif deposit_menu == 7 :
            requested_amount = int(input("Please enter the amount:"))
            if requested_amount%10 == 0:
              balance = balance + requested_amount
              print(f"You have added {requested_amount}.Your new balance is:{round(balance,2)}")
              print(main_menu_message)
            else :
              print ("Sorry we can only accept deposits of over £10 in notes.\nPlease try again.")      
              print(main_menu_message)
          elif deposit_menu == 8:
            print(main_menu_message)
        elif main_menu == 9 :
          print("Goodbye!\nDon't forget to take your card. ")
          keep_going = False
          keep_going_1 = False
        else :
          print("Error. Please enter a valid option.")
          print(main_menu_message)
          keep_going = False
  else:
    print("Incorrect pin. Please try again.Goodbye!")
    keep_going_1 = True

main_menu_message = "Main Menu \n Please choose one of the following options : \n  1 - Display balance\n  2 - Withdraw funds \n  3 - Deposit funds\n  9 - Return card \n "
pin_entered = input("Please enter your pin:")

pin_entry(pin_entered)
# Out:
# 5.51
# Hello !
# Welcome to the Northen Frock Bank
# Please enter your pin:1234
# Main Menu
#  Please choose one of the following options :
#   1 - Display balance
#   2 - Withdraw funds
#   3 - Deposit funds
#   9 - Return card
#
# 9
# Goodbye!
# Don't forget to take your card.
